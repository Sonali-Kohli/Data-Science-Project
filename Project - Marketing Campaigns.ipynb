# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from scipy import stats
import datetime
# color-maps
import matplotlib.cm as cm

# %%
df = pd.read_csv("marketing_data.csv")

# %% [markdown]
# #### Step 1. Once data is imported, investigate variables like Dt_Customer and Income, etc., and check if they are imported correctly

# %%
df.sample(5)
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 209     263        1945         PhD         Single  $45,576.00         0
# 393    9392        1971  Graduation         Single  $26,954.00         1
# 346   10507        1977    2n Cycle       Divorced  $59,601.00         0
# 1974   4478        1979  Graduation        Married  $63,777.00         1
# 2028   4587        1944      Master          Widow  $45,006.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# 209          0     5/28/14        9        56  ...                  3
# 393          0      5/8/14       17         4  ...                  2
# 346          1     7/25/13       14       691  ...                  7
# 1974         1     3/24/13       87       457  ...                  6
# 2028         0     7/18/13       90       162  ...                  7
#
#       NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  \
# 209                   8             0             0             0
# 393                   7             0             0             0
# 346                   8             0             1             0
# 1974                  8             0             0             0
# 2028                  3             0             0             0
#
#       AcceptedCmp1  AcceptedCmp2  Response  Complain  Country
# 209              0             0         1         0       SP
# 393              0             0         0         0       SP
# 346              0             0         0         0       US
# 1974             0             0         0         0      IND
# 2028             0             0         0         0       SP
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (2240, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
#  15  NumDealsPurchases    2240 non-null   int64
#  16  NumWebPurchases      2240 non-null   int64
#  17  NumCatalogPurchases  2240 non-null   int64
#  18  NumStorePurchases    2240 non-null   int64
#  19  NumWebVisitsMonth    2240 non-null   int64
#  20  AcceptedCmp3         2240 non-null   int64
#  21  AcceptedCmp4         2240 non-null   int64
#  22  AcceptedCmp5         2240 non-null   int64
#  23  AcceptedCmp1         2240 non-null   int64
#  24  AcceptedCmp2         2240 non-null   int64
#  25  Response             2240 non-null   int64
#  26  Complain             2240 non-null   int64
#  27  Country              2240 non-null   object
# dtypes: int64(23), object(5)
# memory usage: 490.1+ KB

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', ' Income ',
#        'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency', 'MntWines',
#        'MntFruits', 'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %% [markdown]
# It can be seen that **there are some columns** names in the dataset which **have leading or trailing spaces.** We will rename these columns.

# %%
df = df.rename(columns = lambda x : x.strip())

# %%
df = df.rename(columns = {'Income' : 'Income (In Dollars)'})

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status',
#        'Income (In Dollars)', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
#        'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %% [markdown]
# The **columns have been renamed** and **leading** or **trailing spaces** have been removed.

# %% [markdown]
# #### Step 2. Income values for a few customers are missing. Perform missing value imputation. Assume that the customers with similar education and marital status make the same yearly income, on average. You may have to clean the data before performing this. For data cleaning, look into the categories of education and marital status.

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income (In Dollars)    24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %% [markdown]
# It can be seen that there are **24 Missing values** in the column Income.

# %%
df[df.isnull().any(axis = 1)]
# Out:
#          ID  Year_Birth   Education Marital_Status Income (In Dollars)  \
# 134    8996        1957         PhD        Married                 NaN
# 262    1994        1983  Graduation        Married                 NaN
# 394    3769        1972         PhD       Together                 NaN
# 449    5255        1986  Graduation         Single                 NaN
# 525    8268        1961         PhD        Married                 NaN
# 590   10629        1973    2n Cycle        Married                 NaN
# 899   10475        1970      Master       Together                 NaN
# 997    9235        1957  Graduation         Single                 NaN
# 1096   4345        1964    2n Cycle         Single                 NaN
# 1185   7187        1969      Master       Together                 NaN
# 1213   8720        1978    2n Cycle       Together                 NaN
# 1312   8557        1982  Graduation         Single                 NaN
# 1515   2863        1970  Graduation         Single                 NaN
# 1558   2437        1989  Graduation        Married                 NaN
# 1693   5250        1943      Master          Widow                 NaN
# 1804   7281        1959         PhD         Single                 NaN
# 1858   1612        1981         PhD         Single                 NaN
# 1863   5079        1971  Graduation        Married                 NaN
# 1880  10339        1954      Master       Together                 NaN
# 1967   5798        1973      Master       Together                 NaN
# 1983   2902        1958  Graduation       Together                 NaN
# 2139   3117        1955  Graduation         Single                 NaN
# 2165   7244        1951  Graduation         Single                 NaN
# 2170   1295        1963  Graduation        Married                 NaN
#
#       Kidhome  Teenhome Dt_Customer  Recency  MntWines  ...  \
# 134         2         1    11/19/12        4       230  ...
# 262         1         0    11/15/13       11         5  ...
# 394         1         0      3/2/14       17        25  ...
# 449         1         0     2/20/13       19         5  ...
# 525         0         1     7/11/13       23       352  ...
# 590         1         0     9/14/12       25        25  ...
# 899         0         1      4/1/13       39       187  ...
# 997         1         1     5/27/14       45         7  ...
# 1096        1         1     1/12/14       49         5  ...
# 1185        1         1     5/18/13       52       375  ...
# 1213        0         0     8/12/12       53        32  ...
# 1312        1         0     6/17/13       57        11  ...
# 1515        1         2     8/23/13       67       738  ...
# 1558        0         0      6/3/13       69       861  ...
# 1693        0         0    10/30/13       75       532  ...
# 1804        0         0     11/5/13       80        81  ...
# 1858        1         0     5/31/13       82        23  ...
# 1863        1         1      3/3/13       82        71  ...
# 1880        0         1     6/23/13       83       161  ...
# 1967        0         0    11/23/13       87       445  ...
# 1983        1         1      9/3/12       87        19  ...
# 2139        0         1    10/18/13       95       264  ...
# 2165        2         1      1/1/14       96        48  ...
# 2170        0         1     8/11/13       96       231  ...
#
#       NumStorePurchases  NumWebVisitsMonth  AcceptedCmp3  AcceptedCmp4  \
# 134                   8                  9             0             0
# 262                   2                  7             0             0
# 394                   3                  7             0             0
# 449                   0                  1             0             0
# 525                   7                  6             0             0
# 590                   3                  8             0             0
# 899                   6                  5             0             0
# 997                   2                  7             0             0
# 1096                  2                  7             0             0
# 1185                  4                  3             0             0
# 1213                  1                  0             0             1
# 1312                  3                  6             0             0
# 1515                 10                  7             0             1
# 1558                 12                  3             0             1
# 1693                 11                  1             0             0
# 1804                  4                  2             0             0
# 1858                  3                  6             0             0
# 1863                  3                  8             0             0
# 1880                  4                  6             0             0
# 1967                  8                  1             0             0
# 1983                  3                  5             0             0
# 2139                  5                  7             0             0
# 2165                  4                  6             0             0
# 2170                  7                  4             0             0
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  Country
# 134              0             0             0         0         0      GER
# 262              0             0             0         0         0       US
# 394              0             0             0         0         0      AUS
# 449              0             0             0         0         0      AUS
# 525              0             0             0         0         0       CA
# 590              0             0             0         0         0      GER
# 899              0             0             0         0         0       US
# 997              0             0             0         0         0      GER
# 1096             0             0             0         0         0      AUS
# 1185             0             0             0         0         0      AUS
# 1213             0             0             0         0         0      IND
# 1312             0             0             0         0         0      AUS
# 1515             0             1             0         0         0       SP
# 1558             0             1             0         0         0       SP
# 1693             1             0             0         1         0      AUS
# 1804             0             0             0         0         0      AUS
# 1858             0             0             0         0         0      AUS
# 1863             0             0             0         0         0      AUS
# 1880             0             0             0         0         0      AUS
# 1967             0             0             0         0         0      GER
# 1983             0             0             0         0         0      AUS
# 2139             0             0             0         0         0      AUS
# 2165             0             0             0         0         0      AUS
# 2170             0             0             0         0         0       CA
#
# [24 rows x 28 columns]

# %%
df['Income (In Dollars)'] = df['Income (In Dollars)'].replace({"\$":'',",":''}, regex = True).astype(float)

# %%
df.describe(include='all')
# Out:
#                   ID   Year_Birth   Education Marital_Status  \
# count    2240.000000  2240.000000        2240           2240
# unique           NaN          NaN           5              8
# top              NaN          NaN  Graduation        Married
# freq             NaN          NaN        1127            864
# mean     5592.159821  1968.805804         NaN            NaN
# std      3246.662198    11.984069         NaN            NaN
# min         0.000000  1893.000000         NaN            NaN
# 25%      2828.250000  1959.000000         NaN            NaN
# 50%      5458.500000  1970.000000         NaN            NaN
# 75%      8427.750000  1977.000000         NaN            NaN
# max     11191.000000  1996.000000         NaN            NaN
#
#         Income (In Dollars)      Kidhome     Teenhome Dt_Customer  \
# count           2216.000000  2240.000000  2240.000000        2240
# unique                  NaN          NaN          NaN         663
# top                     NaN          NaN          NaN     8/31/12
# freq                    NaN          NaN          NaN          12
# mean           52247.251354     0.444196     0.506250         NaN
# std            25173.076661     0.538398     0.544538         NaN
# min             1730.000000     0.000000     0.000000         NaN
# 25%            35303.000000     0.000000     0.000000         NaN
# 50%            51381.500000     0.000000     0.000000         NaN
# 75%            68522.000000     1.000000     1.000000         NaN
# max           666666.000000     2.000000     2.000000         NaN
#
#             Recency     MntWines  ...  NumStorePurchases  NumWebVisitsMonth  \
# count   2240.000000  2240.000000  ...        2240.000000        2240.000000
# unique          NaN          NaN  ...                NaN                NaN
# top             NaN          NaN  ...                NaN                NaN
# freq            NaN          NaN  ...                NaN                NaN
# mean      49.109375   303.935714  ...           5.790179           5.316518
# std       28.962453   336.597393  ...           3.250958           2.426645
# min        0.000000     0.000000  ...           0.000000           0.000000
# 25%       24.000000    23.750000  ...           3.000000           3.000000
# 50%       49.000000   173.500000  ...           5.000000           6.000000
# 75%       74.000000   504.250000  ...           8.000000           7.000000
# max       99.000000  1493.000000  ...          13.000000          20.000000
#
#         AcceptedCmp3  AcceptedCmp4  AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  \
# count    2240.000000   2240.000000   2240.000000   2240.000000   2240.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.072768      0.074554      0.072768      0.064286      0.013393
# std         0.259813      0.262728      0.259813      0.245316      0.114976
# min         0.000000      0.000000      0.000000      0.000000      0.000000
# 25%         0.000000      0.000000      0.000000      0.000000      0.000000
# 50%         0.000000      0.000000      0.000000      0.000000      0.000000
# 75%         0.000000      0.000000      0.000000      0.000000      0.000000
# max         1.000000      1.000000      1.000000      1.000000      1.000000
#
#            Response     Complain  Country
# count   2240.000000  2240.000000     2240
# unique          NaN          NaN        8
# top             NaN          NaN       SP
# freq            NaN          NaN     1095
# mean       0.149107     0.009375      NaN
# std        0.356274     0.096391      NaN
# min        0.000000     0.000000      NaN
# 25%        0.000000     0.000000      NaN
# 50%        0.000000     0.000000      NaN
# 75%        0.000000     0.000000      NaN
# max        1.000000     1.000000      NaN
#
# [11 rows x 28 columns]

# %%
df.groupby(['Education','Marital_Status'])['Income (In Dollars)'].mean()
# Out:
# Education   Marital_Status
# 2n Cycle    Divorced          49395.130435
#             Married           46201.100000
#             Single            53673.944444
#             Together          44736.410714
#             Widow             51392.200000
# Basic       Divorced           9548.000000
#             Married           21960.500000
#             Single            18238.666667
#             Together          21240.071429
#             Widow             22123.000000
# Graduation  Absurd            79244.000000
#             Alone             34176.000000
#             Divorced          54526.042017
#             Married           50800.258741
#             Single            51322.182927
#             Together          55758.480702
#             Widow             54976.657143
# Master      Absurd            65487.000000
#             Alone             61331.000000
#             Divorced          50331.945946
#             Married           53286.028986
#             Single            53530.560000
#             Together          52109.009804
#             Widow             58401.545455
# PhD         Alone             35860.000000
#             Divorced          53096.615385
#             Married           58138.031579
#             Single            53314.614583
#             Together          56041.422414
#             Widow             60288.083333
#             YOLO              48432.000000
# Name: Income (In Dollars), dtype: float64

# %%
df['Income (In Dollars)'] = df.groupby(['Education','Marital_Status'])['Income (In Dollars)'].transform(lambda x : x.fillna(x.mean()))

# %%
df.isna().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income (In Dollars)    0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Response               0
# Complain               0
# Country                0
# dtype: int64

# %% [markdown]
# #### Step 3. Create variables to populate the total number of children, age, and total spending.

# %%
df.columns
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status',
#        'Income (In Dollars)', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Recency',
#        'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
#        'MntSweetProducts', 'MntGoldProds', 'NumDealsPurchases',
#        'NumWebPurchases', 'NumCatalogPurchases', 'NumStorePurchases',
#        'NumWebVisitsMonth', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5',
#        'AcceptedCmp1', 'AcceptedCmp2', 'Response', 'Complain', 'Country'],
#       dtype='object')

# %%
df['Total_Children'] = df['Kidhome'] + df['Teenhome']
df['Age'] = datetime.datetime.now().year - df['Year_Birth']
df['Total_Spending'] = df['MntWines'] + df['MntFruits'] + df['MntMeatProducts'] + df['MntFishProducts'] + df['MntSweetProducts'] + df['MntGoldProds']

# %% [markdown]
# Created 3 new columns: Total_Children, Age and Total_Spending.

# %%
df.sample(5)
# Out:
#          ID  Year_Birth   Education Marital_Status  Income (In Dollars)  \
# 479    9150        1963         PhD         Single              48918.0
# 945    9360        1982  Graduation        Married              37040.0
# 116   11084        1976      Master       Together              65104.0
# 1154   5290        1964         PhD        Married              41551.0
# 2071   5562        1974  Graduation        Married              60093.0
#
#       Kidhome  Teenhome Dt_Customer  Recency  MntWines  ...  AcceptedCmp4  \
# 479         1         1     4/12/14       21        52  ...             0
# 945         0         0      8/8/12       41        86  ...             0
# 116         0         1    11/14/13        4       738  ...             0
# 1154        1         1     8/14/13       51       220  ...             0
# 2071        0         1     6/26/13       92       502  ...             0
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  Country  \
# 479              0             0             0         0         0       SP
# 945              0             0             0         0         0       US
# 116              0             0             0         1         0       CA
# 1154             0             0             0         0         0       CA
# 2071             0             0             0         0         0       SP
#
#       Total_Children  Age  Total_Spending
# 479                2   61              62
# 945                0   42             316
# 116                1   48            1053
# 1154               2   60             279
# 2071               1   50             735
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Steps 4. Create box plots and histograms to understand the distributions and outliers. Perform outlier treatment.

# %%
Q1 = df['Income (In Dollars)'].quantile(0.25)
Q3 = df['Income (In Dollars)'].quantile(0.75)
IQR = Q3 - Q1

# %%
df = df[~((df['Income (In Dollars)'] > (Q3 + 1.5 * IQR)) | (df['Income (In Dollars)'] < (Q1 - 1.5 * IQR)))]

# %%
df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])
# Out:
# <ipython-input-40-5ede84e7ffb2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dt_Customer'] = pd.to_datetime(df['Dt_Customer'])

# %% [markdown]
# #### Step 5. Use ordinal encoding and one hot encoding according to different types of categorical variables

# %%
le = LabelEncoder()
df_origin = df.copy()

cat_cols = df.select_dtypes(include = ['object']).columns

# %%
cat_cols
# Out:
# Index(['Education', 'Marital_Status', 'Country'], dtype='object')

# %%
for col in cat_cols:
    df[col] = le.fit_transform(df[col])
# Out:
# <ipython-input-46-ac9cf5aadcdd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = le.fit_transform(df[col])

# %%
df.sample(5)
# Out:
#         ID  Year_Birth  Education  Marital_Status  Income (In Dollars)  \
# 2232  7232        1973          2               6              42429.0
# 1976  1118        1956          3               3              50965.0
# 145    624        1984          3               4              18890.0
# 892   8523        1968          2               3              19329.0
# 877   5036        1984          4               4              42710.0
#
#       Kidhome  Teenhome Dt_Customer  Recency  MntWines  ...  AcceptedCmp4  \
# 2232        0         1  2014-02-11       99        55  ...             0
# 1976        0         1  2013-02-20       87       544  ...             0
# 145         0         0  2012-11-10        5         6  ...             0
# 892         1         0  2013-12-14       39        24  ...             0
# 877         1         0  2012-11-28       38       252  ...             0
#
#       AcceptedCmp5  AcceptedCmp1  AcceptedCmp2  Response  Complain  Country  \
# 2232             0             0             0         0         0        6
# 1976             0             0             0         0         0        6
# 145              0             0             0         1         0        5
# 892              0             0             0         0         0        1
# 877              0             0             0         0         0        6
#
#       Total_Children  Age  Total_Spending
# 2232               1   51              67
# 1976               1   68             685
# 145                0   40              35
# 892                1   56              60
# 877                1   40             406
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Step 7.1: Older people are not as tech-savvy and probably prefer shopping in-store.

# %%
store_purchases = df[df['Age'] > 50]['NumStorePurchases']
web_purchases = df[df['Age'] > 50]['NumWebPurchases']

# %%
t_stat, p_value = stats.ttest_ind(store_purchases, web_purchases)

# %%
alpha = 0.05
if p_value <= alpha:
    print("People above 50 prefer shopping in-store")
else:
    print("People above 50 do shopping in-store and as well as online both equally.")
# Out:
# People above 50 prefer shopping in-store

# %% [markdown]
# #### Step 7.2: Customers with kids probably have less time to visit a store and would prefer to shop online.

# %%
store_purchases1 = df[df['Total_Children'] > 0]['NumStorePurchases']
web_purchases1 = df[df['Total_Children'] > 0]['NumWebPurchases']

# %%
t_stat, p_value = stats.ttest_ind(store_purchases1, web_purchases1)

# %%
alpha = 0.05
if p_value <= alpha:
    print("People with children prefer shopping in-store")
else:
    print("People with children do shopping in-store and as well as online equally.")
# Out:
# People with children prefer shopping in-store

# %%
mean_store_purchases1 = df[df['Total_Children'] > 0]['NumStorePurchases'].mean()
mean_web_purchases1 = df[df['Total_Children'] > 0]['NumWebPurchases'].mean()

# %%
if mean_store_purchases1 > mean_web_purchases1:
    print("People with children prefer shopping in-store")
else:
    print("People with children prefer shopping online.")
# Out:
# People with children prefer shopping in-store

# %% [markdown]
# Step 7.3: Other distribution channels may cannibalize sales at the store.

# %%
# compare overall NumStorePurchases, NumWebPurchases

# %% [markdown]
# #### Step 7.4: Does the US fare significantly better than the rest of the world in terms of total purchases?

# %%
df_origin['TotalPurchses'] = df['NumWebPurchases'] + df['NumStorePurchases'] + df['NumCatalogPurchases']
total_purchases_by_country = df_origin.groupby('Country')['TotalPurchses'].sum()

# %%
US_purchases = total_purchases_by_country['US']

# %%
rest_of_world_purchases = total_purchases_by_country.sum() - US_purchases

# %%
if US_purchases > rest_of_world_purchases:
    print("The US fares significantly better than the rest of the world in terms of total purchases.")
else:
    print("The US does not fare significantly better than the rest of the world in terms of total purchases.")
# Out:
# The US does not fare significantly better than the rest of the world in terms of total purchases.

# %%
t_stat, p_value = stats.ttest_ind(US_purchases, rest_of_world_purchases)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3621: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
alpha = 0.05
if p_value <= alpha:
    print("The US fares significantly better than the rest of the world in terms of total purchases.")
else:
    print("The US does not fare significantly better than the rest of the world in terms of total purchases.")
# Out:
# The US does not fare significantly better than the rest of the world in terms of total purchases.

# %%
df_origin[df_origin['Complain'] == 1]['Education'].value_counts()
# Out:
# Graduation    14
# 2n Cycle       4
# Master         2
# PhD            1
# Name: Education, dtype: int64
